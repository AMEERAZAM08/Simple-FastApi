# %%
import os  
os.chdir('/workspaces/Simple-FastApi/fastapi-celery-project')
from main import  app, divide

# %%
task = divide.delay(1, 2)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /opt/python/3.10.4/lib/python3.10/site-packages/redis/connection.py:559, in Connection.connect(self)
#     558 try:
# --> 559     sock = self._connect()
#     560 except socket.timeout:
#
# File /opt/python/3.10.4/lib/python3.10/site-packages/redis/connection.py:615, in Connection._connect(self)
#     614 if err is not None:
# --> 615     raise err
#     616 raise socket.error("socket.getaddrinfo returned an empty list")
#
# File /opt/python/3.10.4/lib/python3.10/site-packages/redis/connection.py:603, in Connection._connect(self)
#     602 # connect
# --> 603 sock.connect(socket_address)
#     605 # set the socket_timeout now that we're connected
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
task
